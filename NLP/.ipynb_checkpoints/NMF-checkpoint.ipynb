# %%
# necessary libraries

# %pylab inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# read data to DataFrame
import pandas as pd
import numpy as np

# feature extraction
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.tokenize.casual import casual_tokenize

# pipeline
from sklearn.pipeline import Pipeline

# model selection
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score,  classification_report, confusion_matrix, make_scorer
from sklearn.base import BaseEstimator, TransformerMixin

# decomposition PCA
from sklearn.decomposition import IncrementalPCA, TruncatedSVD
from sklearn.decomposition import NMF, LatentDirichletAllocation

# classifiers
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier

#learning
from sklearn.model_selection import learning_curve

# time
from time import time

# progress bar
from tqdm import tqdm

# string
import string

# %%
n_top_words = 20
n_components = 20

# %%
# load data
PATH_TO_DATA = './simplesentiment/'
files = ['products_sentiment_train.tsv', 'products_sentiment_test.tsv']
train =  pd.read_csv(PATH_TO_DATA+files[0], sep = '\t', header = None, names = ['text', 'target'])
# train, taget, test
data_samples = train.text
y = train.target

# %% [markdown]
# ## LDiA model

# %% [markdown]
# ### vectorizer

# %%
punctuation = set(f"{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’`")

# data transformer - vectorizer
vectorizer = CountVectorizer(ngram_range=(1, 1),
                             min_df=2,
                             tokenizer=casual_tokenize,
                             analyzer='word',
                             stop_words='english')

# %%
LDiA = LatentDirichletAllocation(n_components=n_components,
                                 max_iter=10,
                                 learning_method='online',
                                 learning_offset=50.,
                                 random_state=0,
                                 n_jobs=-1)

ldia = Pipeline(steps=[('vectorizer', vectorizer), ('ldia', LDiA)])

print("Fitting LDiA model with term counts features ...")
t0 = time()
Xt = ldia.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# Fitting LDiA model with term counts features ...
# done in 6.477s.

# %%
display(Xt[:5])
print(Xt.shape)
# Out:
# array([[0.87023795, 0.07039435, 0.0593677 ],
#        [0.03744174, 0.25364475, 0.70891351],
#        [0.02751181, 0.03110632, 0.94138187],
#        [0.02263379, 0.95309256, 0.02427366],
#        [0.93516472, 0.03184342, 0.03299185]])
# (2000, 3)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %% [markdown]
# ## Components in LDiA

# %%
print("\nTopics in LDA model:")
feature_names = vectorizer.get_feature_names()
print_top_words(LDiA, feature_names, n_top_words)
# Out:
# Topics in LDA model:
# Topic #0: shutter lag avoid complete quite seconds depth live minimum automatic shoot focusing point makes fuss . problems time product works
# Topic #1: . router lens works adjustment table viewfinder really hand ring knob depth documentation sd500 tones user old & learning negative
# Topic #2: hitachi m12v router personal local beast hp time books woodworking stores internet 4 came choice , best price . /
# Topic #3: best . buy large canon g3 mp3 memory considering camera , player 4mp price portable hype hot stuff sure highly
# Topic #4: drops prints signals backyard strong laid beautiful coverage recent house wider bargain wrt 54g area wireless . plus available packed
# Topic #5: switched print hip huge apex package . tiny awesome happy camera easy listening ' looks design song shape quality firmware
# Topic #6: . wheel software - jack design headphone intuitive scroll signal comes job , ; xp controls n't ratio creative kinda
# Topic #7: . , ' ) ( camera phone s great - t use quality good like easy features ipod battery just
# Topic #8: . music service easy use player files creative , love ; customer bags ) - fast click transfer songs gb
# Topic #9: horrible parts strap access gets . way need router camera switch got problems wma working seamless - think pretty fast
# Topic #10: costly stinky refills genie diaper . responding reply initially pressing protects bluetooth automated cnet qualities end case model poor phones
# Topic #11: respond period weeks reply kids item 24 claim broke month loose automatically certain hour copy . folder , headphone jack
# Topic #12: . 4 did button n't manual / 5 scroll mode * ) stars focus times wo movies , 1 play
# Topic #13: hear home environment piece earpiece business configure office hardware corporate saying noisy game pay players . wrt , small 54g
# Topic #14: , . diapers make holds playlists calls % open using difficult display options times fly huge list application lots presets
# Topic #15: image raw file produced matter flaw accurate present hangs 640x480 reset minor format . film , visible microphone images does
# Topic #16: . , " ! ' - player s dvd problems t ) diaper ( just problem play norton cd software
# Topic #17: trial fell love computer . firewall antivirus downloaded version does security internet nx card text convenient pads 2.5 reliability "
# Topic #18: ... battery life . plays t-mobile check seriously lasted broken format damage rebate icons treat unbelievable apart showing advice heed
# Topic #19: messages ridiculous highs . deeper popping organizing downloaded captured low constantly memory functions common wasn phone given stars things t

# %% [markdown]
# # PLots

# %% [markdown]
# ## 2-D

# %%
n_components = 2

LDiA = LatentDirichletAllocation(n_components=n_components,
                                 max_iter=10,
                                 learning_method='online',
                                 learning_offset=50.,
                                 random_state=0,
                                 n_jobs=-1)

ldia = Pipeline(steps=[('vectorizer', vectorizer), ('ldia', LDiA)])

print("Plotting 2D LDiA model with term counts features ...")
t0 = time()
Xt = ldia.fit_transform(data_samples)


def d2_plot(Xt, y):
    positive = Xt[y == 1]
    negative = Xt[y == 0]
    plt.scatter(positive[:, 1], positive[:, 0], color='green', s=0.2)
    plt.scatter(negative[:, 1], negative[:, 0], color='red', s=0.2)


d2_plot(Xt, y)

print("done in %0.3fs." % (time() - t0))
# Out:
# Plotting 2D LDiA model with term counts features ...
# done in 5.537s.

# %% [markdown]
# ## 3-D

# %%
n_components = 3

LDiA = LatentDirichletAllocation(n_components=n_components,
                                 max_iter=10,
                                 learning_method='online',
                                 learning_offset=50.,
                                 random_state=0,
                                 n_jobs=-1)

ldia = Pipeline(steps=[('vectorizer', vectorizer), ('ldia', LDiA)])

print("Plotting 3D LDiA model with term counts features ...")
t0 = time()
Xt = ldia.fit_transform(data_samples)


def d3_plot(Xt, y):
    positive = Xt[y == 1]
    negative = Xt[y == 0]
    fig = plt.figure(figsize=(20, 10))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(positive[:, 0],
               positive[:, 1],
               positive[:, 2],
               color='blue',
               s=0.5,
               alpha=0.5)
    ax.scatter(negative[:, 0],
               negative[:, 1],
               negative[:, 2],
               color='red',
               s=1)
    plt.xlim((-1, 1))
    plt.ylim((-1, 1))
    ax.set_zlim(-1, 1)


d3_plot(Xt, y)
print("done in %0.3fs." % (time() - t0))
# Out:
# Plotting 3D LDiA model with term counts features ...
# done in 5.434s.

# %% [markdown]
# ## Classifiers

# %%
# split data
def split_data(X, y, rs):
    test_portion = 0.33
    return train_test_split(X,
                            y,
                            test_size=test_portion,
                            random_state=int(rs),
                            shuffle=True,
                            stratify=y)


# data transformation
def transform_data(train, validation, t):
    t.fit(train)
    return t.transform(train), t.transform(validation)

# %%
from sklearn.svm import SVC

# classifier = SVC(kernel = 'rbf', random_state=3, class_weight='balanced', probability = True)
r_seed = 15

# %%
from sklearn.naive_bayes import ComplementNB
classifier = ComplementNB()

# %% [markdown]
# ### Search opt. n_components

# %%
# split data to train/validation sets
X_train, X_validation, y_train, y_val = split_data(data_samples, y, r_seed)

scores = []
lim = 30
n_range = np.linspace(1, lim, lim).astype(int)
scorer = accuracy_score
# scorer = roc_auc_score

for n in tqdm(n_range):
    # decompositor
    LDiA = LatentDirichletAllocation(n_components=n,
                                     max_iter=5,
                                     learning_method='online',
                                     learning_offset=10.,
                                     random_state=0,
                                     n_jobs=-1)
    # transformer
    pipe = Pipeline(steps=[('vectorizer',
                            vectorizer), ('decomposition',
                                          LDiA), ('classifier', classifier)])
    # fit classifier with train data
    pipe.fit(X_train, y_train)
    # get predictions as probabilities [0..1]
    prob_scores = pipe.predict_proba(X_validation)[:, 1]
    score = scorer(y_val, (prob_scores>0.5).astype(int))
    scores.append(score)

plt.plot(n_range, scores)
# Out:
# 100%|██████████| 30/30 [01:10<00:00,  2.34s/it]

# %%
np.mean(scores), np.std(scores)
# Out:
# (0.5953535353535353, 0.049740577894477715)
