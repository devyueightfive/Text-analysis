# %%
# necessary libraries

# %pylab inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# read data to DataFrame
import pandas as pd
import numpy as np

# feature extraction
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.tokenize.casual import casual_tokenize

# pipeline
from sklearn.pipeline import Pipeline

# model selection
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score,  classification_report, confusion_matrix, make_scorer
from sklearn.base import BaseEstimator, TransformerMixin

# decomposition PCA
from sklearn.decomposition import IncrementalPCA, TruncatedSVD
from sklearn.decomposition import NMF, LatentDirichletAllocation

# classifiers
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier

#learning
from sklearn.model_selection import learning_curve

# time
from time import time

# progress bar
from tqdm import tqdm

# %%
n_top_words = 20
n_components = 20

# %%
# load data
PATH_TO_DATA = './simplesentiment/'
files = ['products_sentiment_train.tsv', 'products_sentiment_test.tsv']
train =  pd.read_csv(PATH_TO_DATA+files[0], sep = '\t', header = None, names = ['text', 'target'])
# train, taget, test
data_samples = train.text
y = train.target

# %% [markdown]
# ## LDiA model

# %%
# data transformer - vectorizer
vectorizer = CountVectorizer(ngram_range=(1, 1),
                             min_df=2,
                             tokenizer=casual_tokenize,
                             analyzer='word')


LDiA = LatentDirichletAllocation(n_components=n_components,
                                 max_iter=10,
                                 learning_method='online',
                                 learning_offset=50.,
                                 random_state=0)

ldia = Pipeline(steps=[('vectorizer', vectorizer), ('ldia', LDiA)])

print("Fitting LDiA model with term counts features ...")
t0 = time()
Xt = ldia.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# Fitting LDiA model with term counts features ...
# done in 7.004s.

# %%
Xt[:5]
# Out:
# array([[0.91117866, 0.04263599, 0.04618535],
#        [0.45761245, 0.01399075, 0.5283968 ],
#        [0.65177577, 0.01243611, 0.33578812],
#        [0.97711095, 0.01151667, 0.01137238],
#        [0.96109021, 0.01899205, 0.01991774]])

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %% [markdown]
# ## Components in LDiA

# %%
print("\nTopics in LDA model:")
feature_names = vectorizer.get_feature_names()
print_top_words(LDiA, feature_names, n_top_words)
# Out:
# Topics in LDA model:
# Topic #0: plays cds smooth 35mm plunging prints environment mp3s indistinguishable . . jpegs earpiece . xtra skipping shortly dvds ( original beautiful
# Topic #1: minimal the pause based 11 " - devices t between ' . less for songs why software can order on
# Topic #2: package beatiful huge worthless tiny print awesome part ten . the , in i with to a quality and times
# Topic #3: wirelessly - this to is . pretty connect still away go case my from half router e ) get ridiculous
# Topic #4: each respond 24 pick friend ringtone saying records listen tough claim period reply audiophile hour to i . great it
# Topic #5: minute tried 75 hung list numbers call sites and , 30 i they . the this along to ( either
# Topic #6: sloppy hangs drops reset depth recent bargain made g3 the available . , on i cameras than it and is
# Topic #7: usb movies 2.0 transfers message disney quick play yesterday our today through wo are . it many played was and
# Topic #8: . , are phone like i nice pretty and with music now quality they into you no might ; but
# Topic #9: bags regular trash ring garbage tones special list fell kitchen beats backlight tall uses unlimited rings roll 6.00 neither profile
# Topic #10: harder update window longer browser recent open 1 . pain a and the then get more to i collet after
# Topic #11: books hp woodworking stores local personal m12v choice hitachi router came time hangs , mind for the and internet again
# Topic #12: , and . my were on camera among bluetooth really phone for baby screen decent gprs good support t-mobile up
# Topic #13: owner pathetic woth installs it anti-virus purchased the . 8 ' and ! , s support customer since works every
# Topic #14: the . i , it and to ' a is with that this of have my for ! in not
# Topic #15: the , . and a software is it feature with there i on out problems using favorite copy but folder
# Topic #16: jack none headset - > locking casing random reported daily being reviewers no library mm connected despite 2.5 recognize wonderfully
# Topic #17: fuss minimum . with it works the to a this i router too much not money installation last another has
# Topic #18: the , . is a and to it of you i ) ' this for ( in with - as
# Topic #19: . that is the to a this you cool compatible , ringtones at doesn most ' sound everything allows light

# %% [markdown]
# # PLots

# %% [markdown]
# ## 2-D

# %%
n_components = 2

LDiA = LatentDirichletAllocation(n_components=n_components,
                                 max_iter=10,
                                 learning_method='online',
                                 learning_offset=50.,
                                 random_state=0)

ldia = Pipeline(steps=[('vectorizer', vectorizer), ('ldia', LDiA)])

print("Plotting 2D LDiA model with term counts features ...")
t0 = time()
Xt = ldia.fit_transform(data_samples)

def d2_plot(Xt, y):
    positive = Xt[y == 1]
    negative = Xt[y == 0]
    plt.scatter(positive[:, 1], positive[:, 0], color='green', s=0.2)
    plt.scatter(negative[:, 1], negative[:, 0], color='red', s=0.2)
    
d2_plot(Xt, y)
    
print("done in %0.3fs." % (time() - t0))
# Out:
# Plotting 2D LDiA model with term counts features ...
# done in 7.864s.

# %% [markdown]
# ## 3-D

# %%
n_components = 3

LDiA = LatentDirichletAllocation(n_components=n_components,
                                 max_iter=10,
                                 learning_method='online',
                                 learning_offset=50.,
                                 random_state=0)

ldia = Pipeline(steps=[('vectorizer', vectorizer), ('ldia', LDiA)])

print("Plotting 3D LDiA model with term counts features ...")
t0 = time()
Xt = ldia.fit_transform(data_samples)

def d3_plot(Xt, y):
    positive = Xt[y == 1]
    negative = Xt[y == 0]
    fig = plt.figure(figsize = (20, 10))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(positive[:, 0], positive[:, 1], positive[:, 2], color='blue', s=0.5, alpha = 0.5)
    ax.scatter(negative[:, 0], negative[:, 1], negative[:, 2],color='red', s=1)
    plt.xlim((-1, 1))
    plt.ylim((-1, 1))
    ax.set_zlim(-1, 1)
    
d3_plot(Xt, y)
print("done in %0.3fs." % (time() - t0))
# Out:
# Plotting 3D LDiA model with term counts features ...
# done in 6.775s.

# %% [markdown]
# ## Classifier : LogisticRegression

# %%
classifier = LogisticRegression(random_state=0, C=5)
r_seed = 22

# split data to train/validation sets
X_train, X_validation, y_train, y_val = split_data(X, y, r_seed)

scores = []
lim = 60
n_range = np.linspace(1, lim, lim).astype(int)
for n in tqdm(n_range):
    # decompositor
    LDiA = LatentDirichletAllocation(n_components=n_components,
                                     max_iter=10,
                                     learning_method='online',
                                     learning_offset=50.,
                                     random_state=0)
    # transformer
    pipe = Pipeline(steps=[('vectorizer',
                            vectorizer), ('decomposition',
                                          LDiA), ('classifier', classifier)])
    # fit classifier with train data
    pipe.fit(X_train, y_train)
    # get predictions as probabilities [0..1]
    prob_scores = pipe.predict_proba(X_validation)[:, 1]
    score = roc_auc_score(y_val, prob_scores)
    scores.append(score)

plt.plot(n_range, scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-7b3d10636662> in <module>
#       3
#       4 # split data to train/validation sets
# ----> 5 X_train, X_validation, y_train, y_val = split_data(X, y, r_seed)
#       6
#       7 scores = []
#
# NameError: name 'split_data' is not defined
